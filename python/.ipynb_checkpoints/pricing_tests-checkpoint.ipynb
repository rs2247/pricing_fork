# %% [markdown]
# ## <center><u>Pricing - Tests</u><a name='home' /></center>

# %%
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
from googleapiclient.discovery import build
from sqlalchemy import create_engine
from jupyterthemes import jtplot
from pandas import ExcelWriter
from selenium import webdriver
from datetime import datetime
from scipy.stats import norm
from math import sqrt



import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import pandas.io.sql as psql
import scipy.stats as st
import psycopg2 as pg
import datetime as dt
import seaborn as sns
import pandas as pd
import numpy as np
import scipy as sp
import getpass
import os.path
import pickle
import math

from functions import *

jtplot.style()

# %%
user='rafael.okida'
pwd=getpass.getpass('Password:')
host='172.31.31.218'
# Out:
# Password:········

# %% [markdown]
# <u><b><center>New Test</center></b></u>

# %%
name='test minimum price 149.9'
description=''
start_date=dt.datetime.strftime(datetime.datetime.now(),"%Y-%m-%d %H:%M")
pricing_test=pd.DataFrame.from_dict({'name':[name],'description':[description],'start_date':[start_date]})
insert_table(pricing_test,user,pwd,host,'pricing_tests')

# %% [markdown]
# <u><b><center>Analysis</center></b></u>

# %%
test_id=3
query_analysis = open('{0}/test_offer_analysis.sql'.format(sql_dir),'r').read()
query_analysis=query_analysis.format(test_id)
analysis=run_query(query_analysis,'bi',user,pwd,host)

# %%
rpc=global_analysis(analysis,user,pwd,host)
rpc['rpc']
# Out:
#    paid  total  customers    revenue     aov    rpo    rpc
# 0   793   3329       2383   94971.52  119.76  28.53  39.85
# 1   916   4206       3022  139803.84  152.62  33.24  46.26

# %%
pd.DataFrame.from_dict(offer_analysis(analysis[analysis['customer_id'].isin(rpc['customers'])]))[['paid','total','customers','revenue','aov','rpo','rpc']]
# Out:
#    paid  total  customers    revenue         aov        rpo       rpc
# 0   736   2492       2383   85767.03  116.531291  34.416946  35.99120
# 1   823   3206       3022  123375.75  149.909781  38.482767  40.82586

# %% [markdown]
# <u><b><center>Rollback</center></b></u>

# %%
offer_ids=(18710374,18710375,18710503,18710376,18710504,18710377,18710505,18710378,18710379,18710506,18710380,18710381,18710382,18710383,18710384,18710385,18710386,18710387,18710388,18710389,18710390,18710391,18710392,18710393,18710394,18710395,18710396,18710397,18710628,18710398,18710629,18710399,18710630,18710400,18710631,18710401,18710632,18710402,18710633,18710403,18710634,18710404,18710635,18710405,18710636,18710406,18710637,18710407,18710638,18710408,18710639,18710640,18710409,18710410,18710641,18710411,18710412,18710642,18710413,18710414,18710643,18710415,18710416,18710644,18710417,18710418,18710645,18710419,18710646,18710420,18710647,18710421,18710648,18710422,18710423,18710649,18710650,18710424,18710651,18710652,18710425,18710426,18710653,18710654,18710427,18710655,18710428,18710656,18710429,18710657,18710430,18710658,18710431,18710659,18710432,18710660,18710433,18710434,18710661,18710435,18710436,18710662,18710437,18710438,18710663,18710439,18710664,18710440,18710665,18710441,18710442,18710443,18710444,18710445,18710446,18710447,18710448,18710449,18710450,18710451,18710452,18710453,18710454,18710455,18710456,18710457,18710458,18710459,18710460,18710461,18710462,18710463,18710464,18710465,18710466,18710467,18710468,18710469,18710470,18710471,18710472,18710473,18710474,18710475,18710476,18710477,18710478,18710479,18710480,18710481,18710482,18710483,18710484,18710485,18710486,18710487,18710488,18710489,18710490,18710491,18710492,18710493,18710494,18710495,18710496,18710497,18710498,18710499,18710500,18710501,18710502,18710666,18710667,18710668,18710669,18710670,18710671,18710672,18710673,18710674,18710675,18710676,18710677,18710678,18710679,18710680,18710681,18710682,18710683,18710684,18710685,18710686,18710687,18710688,18710689,18710690,18710691,18710692,18710693,18710694,18710695,18710696,18710697,18710698,18710699,18710700,18710701,18710702,18710703,18710704,18710705,18710706,18710707,18710708,18710709,18710710,18710711,18710712,18710713,18710714,18710715,18710716,18710717,18710718,18710719,18710720,18710721,18710722,18710723,18710724,18710725,18710726,18710727,18710728,18710729,18710730,18710731,18710732,18710733,18710734,18710735,18710736,18710737,18710738,18710739,18710740,18710741,18710507,18710508,18710509,18710510,18710511,18710512,18710513,18710514,18710515,18710516,18710517,18710518,18710519,18710520,18710521,18710522,18710523,18710524,18710525,18710526,18710527,18710528,18710529,18710530,18710531,18710532,18710533,18710534,18710535,18710536,18710537,18710538,18710539,18710540,18710541,18710542,18710543,18710544,18710545,18710546,18710547,18710548,18710549,18710550,18710551,18710552,18710553,18710554,18710555,18710556,18710557,18710558,18710559,18710560,18710561,18710562,18710563,18710564,18710565,18710566,18710567,18710568,18710569,18710570,18710571,18710572,18710573,18710574,18710575,18710576,18710577,18710578,18710579,18710580,18710581,18710582,18710583,18710584,18710585,18710586,18710587,18710588,18710589,18710590,18710591,18710592,18710593,18710594,18710595,18710596,18710597,18710598,18710599,18710600,18710601,18710602,18710603,18710604,18710605,18710606,18710607,18710608,18710609,18710610,18710611,18710612,18710613,18710614,18710615,18710616,18710617,18710618,18710619,18710620,18710621,18710622,18710623,18710624,18710625,18710626,18710627)

# %%
test_id=8
ies_id=915
remove_disabled(user,pwd,host)
#rollback=rollback_offers(offer_ids,user,pwd,host)
#rollback=rollback_test(test_id,user,pwd,host)
rollback=rollback_ies(ies_id,test_id,user,pwd,host)
while len(rollback['df'])>0:
    remove_disabled(user,pwd,host)
    upload_xlsx(rollback['file_name'],user,pwd)
    remove_offers(tuple(rollback['df']['offer_id']),\
                  dt.datetime.strftime(datetime.datetime.now(),"%Y-%m-%d %H:%M"),\
                  user,pwd,host)
    #rollback=rollback_offers(offer_ids,user,pwd,host)
    #rollback=rollback_test(test_id,user,pwd,host)
    rollback=rollback_ies(ies_id,test_id,user,pwd,host)

# %%
remove_disabled(user,pwd,host)

# %%
remove_offers(tuple(rollback['df']['offer_id']),\
              dt.datetime.strftime(datetime.datetime.now(),"%Y-%m-%d %H:%M"),\
              user,pwd,host)

# %%
rollback=rollback_ies(1639,1,user,pwd,host)

# %%
disabled_query = open('{0}/test_disabled_offers.sql'.format(sql_dir),'r').read()
disabled=run_query(disabled_query,'bi',user,pwd,host)

# %%
if len(disabled['offer_id'])>0:
    remove_offers(tuple(disabled['offer_id']),\
                  dt.datetime.strftime(datetime.datetime.now(),"%Y-%m-%d %H:%M"),\
                  user,pwd,host)

# %% [markdown]
# <u><b><center>Insert from .xlsx</center></b></u>

# %%
data=pd.read_excel(xlsx_dir+'/test_upload_3_2019_03_15_16_39.xlsx')
test_id=3

# %%
data1=data.copy()
data1['original_price']=None
data1['alternative']=None
data1['price']=None
data1['test_id']=test_id
aux=[]
for i in range(len(data)):
    aux.append((data['pre_enrollment_fees'][i].split('|')[0]))
data1=data1.assign(original_price=aux)
data1=data1.assign(alternative=1)
data1=data1.assign(price=aux)

data2=data.copy()
data2['original_price']=None
data2['alternative']=None
data2['price']=None
data2['test_id']=test_id
aux2=[]
for i in range(len(data)):
    aux2.append((data['pre_enrollment_fees'][i].split('|')[1]))
data2=data2.assign(original_price=aux)
data2=data2.assign(alternative=2)
data2=data2.assign(price=aux2)
'''
data3=data.copy()
data3['original_price']=None
data3['alternative']=None
data3['price']=None
data3['test_id']=test_id
aux3=[]
for i in range(len(data)):
    aux3.append((data['pre_enrollment_fees'][i].split('|')[2]))
data3=data3.assign(original_price=aux)
data3=data3.assign(alternative=3)
data3=data3.assign(price=aux3)
'''
# Out:
# "\ndata3=data.copy()\ndata3['original_price']=None\ndata3['alternative']=None\ndata3['price']=None\ndata3['test_id']=test_id\naux3=[]\nfor i in range(len(data)):\n    aux3.append((data['pre_enrollment_fees'][i].split('|')[2]))\ndata3=data3.assign(original_price=aux)\ndata3=data3.assign(alternative=3)\ndata3=data3.assign(price=aux3)\n"

# %%
test=data1.append(data2)#.append(data3)

# %%
if len(test)>0:
    start_date=dt.datetime.strftime(datetime.datetime.now(),"%Y-%m-%d %H:%M")
    test['start_date']=start_date
    insert_table(test[['test_id','offer_id','original_price','start_date']]\
        .drop_duplicates(),user,pwd,host,'pricing_offers')
    insert_table(test[['test_id','offer_id','alternative','price']]\
        .drop_duplicates(),user,pwd,host,'pricing_alternatives')

# %% [markdown]
# <u><b><center>Change Ratio</center></b></u>

# %%
test_id=8
l=len(rpc['rpc'])
n=10
s_rpc=0
for i in range(l):
    s_rpc+=(rpc['rpc'].rpc[i]-min(rpc['rpc'].rpc))\
            +(np.average(rpc['rpc'].rpc)-min(rpc['rpc'].rpc))\
            *np.sqrt(2*np.log(sum(rpc['rpc'].customers))/rpc['rpc'].customers[i])
ratio=[]
for i in range(l):
    ratio.append(int(round((n-l)*((rpc['rpc'].rpc[i]-min(rpc['rpc'].rpc))\
            +(np.average(rpc['rpc'].rpc)-min(rpc['rpc'].rpc))\
            *np.sqrt(2*np.log(sum(rpc['rpc'].customers))/rpc['rpc'].customers[i]))/s_rpc+1)))

# %%
query=open('{0}/test_alternatives.sql'.format(sql_dir),'r').read()
query=query.format(test_id,l)
offer_alternatives=run_query(query,'bi',user,pwd,host)

# %%
new_test={'offer_ids':[],'pefs':[]}
for i, o in offer_alternatives.iterrows():
    new_test['offer_ids'].append(o['offer_id'])
    new_pefs=''
    for i in range(len(o['alternatives'])):
        for j in range(ratio[i]):
            new_pefs+=str(round(float(o['prices'][i])+0.01*j,2))+'|'
    new_test['pefs'].append(new_pefs[:-1])
new_df=pd.DataFrame.from_dict(new_test)
for g, df in new_df.groupby(np.arange(len(new_df)) // 16384):
    test=df2xlsx(df)
    #upload_xlsx(test['file_name'])
    print('up!')
# Out:
# up!

# %%
days=pd.date_range(start=analysis['order_created_at'].min().date(),end=analysis['order_created_at'].max().date())
revenue=pd.DataFrame(columns=['day','daily_revenue','total_revenue'])
try:
    del analysis['order_date']
except:
    pass
analysis.insert(0, 'order_date', None)
for i,o in enumerate(analysis['order_created_at']):
    try:
        analysis.loc[i,'order_date']=analysis['order_created_at'][i].date()
    except:
        pass
prices=[1,2]

# %%
revenue=pd.DataFrame(columns=['day','daily_revenue','total_revenue','price'])
for price in prices:
    exec("""for day in days:
    revenue_aux={'day':[day.date()],\
                'daily_revenue':[analysis[(analysis['checkout_step']=='paid')\
                                              &(analysis['order_date']==day.date())\
                                              &(analysis['alternative']=="""+str(price)+""")]['coupon_price'].sum()],\
                'total_revenue':[analysis[(analysis['checkout_step']=='paid')\
                                              &(analysis['order_date']<=day.date())\
                                              &(analysis['alternative']=="""+str(price)+""")]['coupon_price'].sum()],\
                'price':"""+str(price)+"""}
    revenue = revenue.append(pd.DataFrame.from_dict(revenue_aux), ignore_index=True,sort=False)""")
plt.plot(revenue[revenue['price']==1]['day']\
     ,revenue[revenue['price']==1]['total_revenue']\
     /len(analysis[analysis['alternative']==1])\
     ,label='a')
plt.plot(revenue[revenue['price']==2]['day']\
         ,revenue[revenue['price']==2]['total_revenue']\
         /len(analysis[analysis['alternative']==2])\
         ,label='b')
'''
plt.plot(revenue[revenue['price']=='c_price']['day']\
         ,revenue[revenue['price']=='c_price']['total_revenue']\
         /len(analysis[date_analysis['alternative']==3])\
         ,label='c')
 '''
#plt.plot(revenue[revenue['price']=='a_price']['day'],revenue[revenue['price']=='a_price']['total_revenue'],label='a')
#plt.plot(revenue[revenue['price']=='b_price']['day'],revenue[revenue['price']=='b_price']['total_revenue'],label='b')
plt.legend(loc='lower right')

# %%
analysis
# Out:
#      order_date       id           order_created_at  offer_id  customer_id  \
# 0          None  7065571 2019-03-01 20:17:03.158344  14560158    337718917
# 1          None  7065829 2019-03-01 20:40:29.929119  14063675    340224538
# 2          None  7066093 2019-03-01 21:01:49.553954  16187862    321932000
# 3          None  7066450 2019-03-01 21:38:55.851845  14693670    338102885
# 4          None  7066573 2019-03-01 21:51:56.339982  17068851    340235308
# 5          None  7066671 2019-03-01 22:00:50.216651  17068920    108246251
# 6          None  7066716 2019-03-01 22:04:30.668711  16187106    338664606
# 7          None  7066789 2019-03-01 22:11:34.533585  15871222    340207849
# 8          None  7066807 2019-03-01 22:13:28.243388  14057871    332446031
# 9          None  7066847 2019-03-01 22:17:45.311549  17068772     55983550
# 10         None  7067019 2019-03-01 22:35:05.369912  14775497    340059251
# 11         None  7067156 2019-03-01 22:49:56.947458  17068959    328637487
# 12         None  7067249 2019-03-01 23:00:04.326421  17029214    340244996
# 13         None  7067761 2019-03-01 23:49:55.293190  16873668      9926306
# 14         None  7067822 2019-03-01 23:55:02.868763  17068959    313578910
# 15         None  7067891 2019-03-02 00:01:11.169480  17068736    340254203
# 16         None  7067974 2019-03-02 00:09:39.248297  15956976    340255580
# 17         None  7068107 2019-03-02 00:21:44.230533  17068664    330040663
# 18         None  7068127 2019-03-02 00:23:40.020967  16659556    340256671
# 19         None  7068136 2019-03-02 00:24:14.817791  13487785    325254841
# 20         None  7068345 2019-03-02 00:44:56.084687  16440441    330090471
# 21         None  7068421 2019-03-02 00:54:53.914904  17068842    323936694
# 22         None  7068490 2019-03-02 01:01:59.423644  17068852    339121426
# 23         None  7068640 2019-03-02 01:16:32.509233  16627866    340263748
# 24         None  7068667 2019-03-02 01:19:26.489373  17068643    334896391
# 25         None  7068681 2019-03-02 01:20:32.028259  17028667    248554041
# 26         None  7068712 2019-03-02 01:24:22.027619  14056809    335055538
# 27         None  7068730 2019-03-02 01:27:05.236881  17068782    195658869
# 28         None  7068795 2019-03-02 01:39:25.206396  12350368    326313651
# 29         None  7068805 2019-03-02 01:40:51.389773  17071672    338274192
# ...         ...      ...                        ...       ...          ...
# 4253       None  7248095 2019-03-21 19:32:08.811034  17442364    343545012
# 4254       None  7248101 2019-03-21 19:32:39.676955  17068769    343547214
# 4255       None  7248105 2019-03-21 19:33:03.784389  18421859    343546445
# 4256       None  7248126 2019-03-21 19:35:19.475107  17068663    331200434
# 4257       None  7248127 2019-03-21 19:35:21.415697  18430979    328862905
# 4258       None  7248149 2019-03-21 19:37:56.792921  18443620    336498738
# 4259       None  7248155 2019-03-21 19:38:23.459312  14921022    342910959
# 4260       None  7248246 2019-03-21 19:45:28.727834  17068533    343548581
# 4261       None  7248303 2019-03-21 19:51:07.211478  17068769    343516335
# 4262       None  7248336 2019-03-21 19:53:39.304048  18442750    155672926
# 4263       None  7248347 2019-03-21 19:54:38.836886  18422126    331081818
# 4264       None  7248352 2019-03-21 19:55:33.684322  17585891    343548142
# 4265       None  7248369 2019-03-21 19:57:07.633145  17068672    338526156
# 4266       None  7248416 2019-03-21 20:00:41.779688  14367543    334267518
# 4267       None  7248439 2019-03-21 20:02:51.464257  18422923    112664150
# 4268       None  7248448 2019-03-21 20:04:04.360638  17068571    300036075
# 4269       None  7248483 2019-03-21 20:06:17.133141  17068920    254407108
# 4270       None  7248489 2019-03-21 20:06:53.931192  14775947    342966549
# 4271       None  7248541 2019-03-21 20:11:13.700123  17443639    343552869
# 4272       None  7248584 2019-03-21 20:14:06.234465  18421865    339685239
# 4273       None  7248600 2019-03-21 20:14:46.931657  18431130    262866145
# 4274       None  7248601 2019-03-21 20:14:47.636227  17068915    254407108
# 4275       None  7248612 2019-03-21 20:16:09.299412  18423019    343553748
# 4276       None  7248626 2019-03-21 20:17:15.205091  18422839    283240255
# 4277       None  7248633 2019-03-21 20:17:45.949715  16911171    328805865
# 4278       None  7248672 2019-03-21 20:21:28.426071  16569230    343518268
# 4279       None  7248706 2019-03-21 20:24:49.008297  18421868    343225533
# 4280       None  7248710 2019-03-21 20:25:24.882215  17068731    250242682
# 4281       None  7248717 2019-03-21 20:25:41.442317  17646422    276501752
# 4282       None  7248731 2019-03-21 20:26:23.926405  17068663    342390873
#
#       university_id                     university_name checkout_step  \
# 0               283                             UNYLEYA      commited
# 1              1601                               UNISA    registered
# 2                67                             UNIFRAN          paid
# 3              1572                             UninCor    registered
# 4              2892               UNIP - Aqui Você Pode    registered
# 5              2901            UNIPLAN - Aqui Você Pode      commited
# 6                27           UNICSUL - Cruzeiro do Sul    registered
# 7              1379  Centro Universitário São Camilo SP          paid
# 8              1601                               UNISA          paid
# 9              2892               UNIP - Aqui Você Pode      commited
# 10             2907                    Nezo Educacional      commited
# 11             2892               UNIP - Aqui Você Pode      commited
# 12               24                          ANHANGUERA    registered
# 13             1973                   Instituto Monitor    registered
# 14             2892               UNIP - Aqui Você Pode    registered
# 15             2892               UNIP - Aqui Você Pode      commited
# 16             1721                                USCS          paid
# 17             2892               UNIP - Aqui Você Pode      commited
# 18             2284                   Instituto Passo 1      commited
# 19             2667                               ETOSP    registered
# 20             2368                          GSA ENSINO      commited
# 21             2892               UNIP - Aqui Você Pode          paid
# 22             2892               UNIP - Aqui Você Pode          paid
# 23               66                             UNOESTE      commited
# 24             2901            UNIPLAN - Aqui Você Pode    registered
# 25               24                          ANHANGUERA      commited
# 26             1601                               UNISA    registered
# 27             2892               UNIP - Aqui Você Pode      commited
# 28             2349                      Faculdade Alfa    registered
# 29              890    FASM - Faculdade Santa Marcelina          paid
# ...             ...                                 ...           ...
# 4253             25                                UNIP    registered
# 4254           2892               UNIP - Aqui Você Pode    registered
# 4255             24                          ANHANGUERA    registered
# 4256           2892               UNIP - Aqui Você Pode      commited
# 4257             24                          ANHANGUERA      commited
# 4258            968                                FCV       commited
# 4259             27           UNICSUL - Cruzeiro do Sul      commited
# 4260           2901            UNIPLAN - Aqui Você Pode      commited
# 4261           2892               UNIP - Aqui Você Pode    registered
# 4262            968                                FCV     registered
# 4263             24                          ANHANGUERA    registered
# 4264           1919               Pós-graduação Estácio    registered
# 4265           2892               UNIP - Aqui Você Pode      commited
# 4266            623      Faculdades Integradas Espírita    registered
# 4267             61                              Unopar      commited
# 4268           2892               UNIP - Aqui Você Pode      commited
# 4269           2901            UNIPLAN - Aqui Você Pode      commited
# 4270           3104                          UCAM - ISO          paid
# 4271             25                                UNIP    registered
# 4272             57                 Faculdade Pitágoras      commited
# 4273             61                              Unopar      commited
# 4274           2901            UNIPLAN - Aqui Você Pode    registered
# 4275             61                              Unopar    registered
# 4276             61                              Unopar    registered
# 4277             19                             Estácio    registered
# 4278           1639                                  UP      commited
# 4279             24                          ANHANGUERA    registered
# 4280           2892               UNIP - Aqui Você Pode    registered
# 4281             24                          ANHANGUERA      commited
# 4282           2892               UNIP - Aqui Você Pode      commited
#
#       full_price  coupon_price  discount_percentage  price  original_price  \
# 0         286.00        143.00                 50.0  143.0          143.00
# 1         239.00         99.90                 30.0   99.9           99.90
# 2         283.27        149.90                 63.0  149.9          103.96
# 3         220.00        110.00                 50.0  110.0          110.00
# 4         139.00         99.90                 30.0   99.9           99.90
# 5         139.00         99.90                 30.0   99.9           99.90
# 6         259.88        149.90                 60.0  149.9          103.95
# 7         263.00         99.90                 32.0   99.9           99.90
# 8         239.00        149.90                 30.0  149.9           99.90
# 9         169.00        149.90                 20.0  149.9          135.20
# 10        200.00        149.90                 20.0  149.9           99.90
# 11        189.00        149.90                 30.0  149.9          132.30
# 12        204.84        149.90                 40.0  149.9          122.90
# 13        176.63         99.90                 30.0   99.9           99.90
# 14        189.00        149.90                 30.0  149.9          132.30
# 15        169.00        149.90                 20.0  149.9          135.20
# 16        297.40        149.90                 50.0  149.9          148.70
# 17        139.00        132.05                  5.0  132.1          132.05
# 18        119.00        149.90                 30.0  149.9           99.90
# 19        525.00        149.90                 10.0  149.9           99.90
# 20        109.90        149.90                 43.0  149.9           99.90
# 21        169.00        149.90                 20.0  149.9          135.20
# 22        209.00        146.30                 30.0  146.3          146.30
# 23        119.00         99.90                 30.0   99.9           99.90
# 24        169.00        149.90                 30.0  149.9          118.30
# 25        204.84        149.90                 40.0  149.9          122.90
# 26        239.00         99.90                 30.0   99.9           99.90
# 27        139.00        111.20                 20.0  111.2          111.20
# 28        170.22        149.90                 25.0  149.9           99.90
# 29        539.00        107.80                 20.0  107.8          107.80
# ...          ...           ...                  ...    ...             ...
# 4253      290.63        149.92                 29.0  149.9           99.90
# 4254      169.00        149.90                 20.0  149.9          135.20
# 4255      526.02        149.90                 77.0  149.9          118.41
# 4256      139.00        132.05                  5.0  132.1          132.05
# 4257      512.48        149.95                 74.0  149.9          134.01
# 4258      272.55        128.10                 53.0  128.1          128.10
# 4259      198.00        138.60                 30.0  138.6          138.60
# 4260      169.00        149.96                 20.0  149.9          135.20
# 4261      169.00        135.20                 20.0  135.2          135.20
# 4262      272.55        128.10                 53.0  128.1          128.10
# 4263      466.48        149.92                 73.0  149.9          127.12
# 4264      189.00        149.94                 50.0  149.9           99.90
# 4265      199.00        149.90                 30.0  149.9          139.30
# 4266      520.00        149.90                 10.0  149.9           99.90
# 4267      450.64        149.97                 69.0  149.9          141.77
# 4268      139.00        132.05                  5.0  132.1          132.05
# 4269      139.00         99.90                 30.0   99.9           99.90
# 4270      298.00        149.90                 50.0  149.9          149.00
# 4271      250.20        149.95                 29.0  149.9           99.90
# 4272      502.84        149.92                 77.0  149.9          115.20
# 4273      492.67        137.90                 72.0  137.9          137.90
# 4274      169.00        149.90                 30.0  149.9          118.30
# 4275      468.04        149.16                 68.0  149.2          149.16
# 4276      454.56        149.90                 69.0  149.9          141.55
# 4277      377.14        113.14                 60.0  113.1          113.14
# 4278      192.22         99.90                 50.0   99.9           99.90
# 4279      494.00        115.20                 77.0  115.2          115.20
# 4280      169.00        149.90                 20.0  149.9          135.20
# 4281      204.84        149.98                 30.0  149.9           99.90
# 4282      139.00        149.90                  5.0  149.9          132.05
#
#       alternative
# 0               1
# 1               1
# 2               2
# 3               1
# 4               1
# 5               1
# 6               2
# 7               1
# 8               2
# 9               2
# 10              2
# 11              2
# 12              2
# 13              1
# 14              2
# 15              2
# 16              2
# 17              1
# 18              2
# 19              2
# 20              2
# 21              2
# 22              1
# 23              1
# 24              2
# 25              2
# 26              1
# 27              1
# 28              2
# 29              1
# ...           ...
# 4253            2
# 4254            2
# 4255            2
# 4256            1
# 4257            2
# 4258            1
# 4259            1
# 4260            2
# 4261            1
# 4262            1
# 4263            2
# 4264            2
# 4265            2
# 4266            2
# 4267            2
# 4268            1
# 4269            1
# 4270            2
# 4271            2
# 4272            2
# 4273            1
# 4274            2
# 4275            1
# 4276            2
# 4277            1
# 4278            1
# 4279            1
# 4280            2
# 4281            2
# 4282            2
#
# [4283 rows x 14 columns]

# %%
reload_test_ies(user,pwd,host,'bi')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-ce2a7e570733> in <module>
# ----> 1 reload_test_ies(user,pwd,host,'bi')
#
# <ipython-input-15-ad15f494dd6b> in reload_test_ies(user, pwd, host, db)
#       6     cursor=conn.cursor()
#       7     cursor.execute('REFRESH MATERIALIZED VIEW test.pricing_ies_tests;')
# ----> 8     cursor.commit()
#
# AttributeError: 'psycopg2.extensions.cursor' object has no attribute 'commit'
